# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/demo_dataset.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/demo_dataset.csv'])
# WARNING: You have a CUDA device, you should probably run with --cuda to speed up training.
#
#  Dataset:  demo_dataset.csv
#
#  Analysis started for target:  Timeser0
# Epoch:  1 [0%] 	Loss: 2.315027
# Epoch: 500 [50%] 	Loss: 1.695508
# Epoch: 1000 [100%] 	Loss: 1.694705
# Potential causes:  [np.int64(1)]
# Validated causes:  []
#
#  Analysis started for target:  Timeser1
# Epoch:  1 [0%] 	Loss: 4.291188
# Epoch: 500 [50%] 	Loss: 0.002134
# Epoch: 1000 [100%] 	Loss: 0.002114
# Potential causes:  [np.int64(0)]
# Validated causes:  [np.int64(0)]
#
#  Analysis started for target:  Timeser2
# Epoch:  1 [0%] 	Loss: 1.740447
# Epoch: 500 [50%] 	Loss: 0.364763
# Epoch: 1000 [100%] 	Loss: 0.364258
# Potential causes:  [np.int64(1), np.int64(0)]
# Validated causes:  [np.int64(1)]
#
#  Analysis started for target:  Timeser3
# Epoch:  1 [0%] 	Loss: 2.264087
# Epoch: 500 [50%] 	Loss: 1.657545
# Epoch: 1000 [100%] 	Loss: 1.654904
# Potential causes:  [np.int64(3), np.int64(1)]
# Validated causes:  []
#
# ===================Results for demo_dataset.csv ==================================
# Timeser0 causes Timeser1 with a delay of 1 time steps.
# Timeser1 causes Timeser2 with a delay of 2 time steps.
# ==================================================================================

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/merged_data.csv --epochs 2000 --log_interval 500 --cuda --hidden_layers 5 --kernel_size 3 --dilation_coefficient 3 --use_cache --plot
# Out:
# Arguments: Namespace(cuda=True, epochs=2000, kernel_size=3, hidden_layers=5, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=3, significance=0.8, plot=True, ground_truth=None, data=['data/merged_data.csv'])
#
#  Dataset:  merged_data.csv
#
#  Analysis started for target:  松木山水库瞬时总流量
# Epoch:  1 [0%] 	Loss: 7092656.000000
# Epoch: 500 [25%] 	Loss: 1675.925171
# Epoch: 1000 [50%] 	Loss: 828.268188
# Epoch: 1500 [75%] 	Loss: 431.409698
# Epoch: 2000 [100%] 	Loss: 514.871460
# Potential causes:  [0, 101, 13]
# Validated causes:  [0]
#
#  Analysis started for target:  松木山水库累计总水量
# Epoch:  1 [0%] 	Loss: 924166.000000
# Epoch: 500 [25%] 	Loss: 60.536015
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/work/runTCDF.py:464
#     450 parser.add_argument(
#     451     '--optimizer',
#     452     type=str,
#    (...)
#     455     help='Optimizer to use (default: Adam)'
#     456 )
#     457 parser.add_argument(
#     458     '--log_interval',
#     459     type=check_positive,
#     460     default=500,
#     461     help='Epoch interval to report loss (default: 500)'
#     462 )
#     463 parser.add_argument(
# --> 464     '--seed',
#     465     type=check_positive,
#     466     default=1111,
#     467     help='Random seed (default: 1111)'
#     468 )
#     469 parser.add_argument(
#     470     '--dilation_coefficient',
#     471     type=check_positive,
#    (...)
#     474     'Dilation coefficient, recommended to be equal to kernel size (default: 4)'
#     475 )
#     476 parser.add_argument(
#     477     '--significance',
#     478     type=float,
#    (...)
#     481     "Significance number stating when an increase in loss is significant enough to label a potential cause as true (validated) cause. See paper for more details (default: 0.8)"
#     482 )
#
# File ~/work/runTCDF.py:284, in main(datafiles, evaluation)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/work/runTCDF.py:210, in runTCDF(datafile)
#     208 precision = recall = 0.
#     209 if float(TPdirect + FPdirect) > 0:
# --> 210   precision = TPdirect / float(TPdirect + FPdirect)
#     211 print("Precision: ", precision)
#     212 if float(TPdirect + FN) > 0:
#
# File ~/work/TCDF.py:96, in findcauses(target, cuda, epochs, kernel_size, layers, log_interval, lr, optimizername, seed, dilation_c, significance, file)
#      94 firstloss = firstloss.item()
#      95 for ep in range(2, epochs + 1):
# ---> 96   scores, realloss = train(
#      97       ep, X_train, Y_train, model, optimizer, log_interval, epochs
#      98   )
#      99 realloss = realloss.item()
#     101 s = sorted(scores.view(-1).cpu().detach().numpy(), reverse=True)
#
# File ~/work/TCDF.py:47, in train(epoch, traindata, traintarget, modelname, optimizer, log_interval, epochs)
#      45 loss = F.mse_loss(output, y)
#      46 loss.backward()
# ---> 47 optimizer.step()
#      49 if epoch % log_interval == 0 or epoch % epochs == 0 or epoch == 1:
#      50   print(
#      51       'Epoch: {:2d} [{:.0f}%] \tLoss: {:.6f}'.format(
#      52           epoch, epochpercentage, loss.item()
#      53       )
#      54   )
#
# File /opt/conda/lib/python3.11/site-packages/torch/optim/optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File /opt/conda/lib/python3.11/site-packages/torch/optim/optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File /opt/conda/lib/python3.11/site-packages/torch/optim/adam.py:244, in Adam.step(self, closure)
#     232     beta1, beta2 = group["betas"]
#     234     has_complex = self._init_group(
#     235         group,
#     236         params_with_grad,
#    (...)
#     241         state_steps,
#     242     )
# --> 244     adam(
#     245         params_with_grad,
#     246         grads,
#     247         exp_avgs,
#     248         exp_avg_sqs,
#     249         max_exp_avg_sqs,
#     250         state_steps,
#     251         amsgrad=group["amsgrad"],
#     252         has_complex=has_complex,
#     253         beta1=beta1,
#     254         beta2=beta2,
#     255         lr=group["lr"],
#     256         weight_decay=group["weight_decay"],
#     257         eps=group["eps"],
#     258         maximize=group["maximize"],
#     259         foreach=group["foreach"],
#     260         capturable=group["capturable"],
#     261         differentiable=group["differentiable"],
#     262         fused=group["fused"],
#     263         grad_scale=getattr(self, "grad_scale", None),
#     264         found_inf=getattr(self, "found_inf", None),
#     265     )
#     267 return loss
#
# File /opt/conda/lib/python3.11/site-packages/torch/optim/optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/optim/adam.py:876, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     873 else:
#     874     func = _single_tensor_adam
# --> 876 func(
#     877     params,
#     878     grads,
#     879     exp_avgs,
#     880     exp_avg_sqs,
#     881     max_exp_avg_sqs,
#     882     state_steps,
#     883     amsgrad=amsgrad,
#     884     has_complex=has_complex,
#     885     beta1=beta1,
#     886     beta2=beta2,
#     887     lr=lr,
#     888     weight_decay=weight_decay,
#     889     eps=eps,
#     890     maximize=maximize,
#     891     capturable=capturable,
#     892     differentiable=differentiable,
#     893     grad_scale=grad_scale,
#     894     found_inf=found_inf,
#     895 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/optim/adam.py:621, in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     616 # Decay the first and second moment running average coefficient
#     617 # Use device beta1 if beta1 is a tensor to ensure all
#     618 # tensors are on the same device
#     619 torch._foreach_lerp_(device_exp_avgs, device_grads, 1 - device_beta1)
# --> 621 torch._foreach_mul_(device_exp_avg_sqs, beta2)
#     623 # Due to the strictness of the _foreach_addcmul API, we can't have a single
#     624 # tensor scalar as the scalar arg (only python number is supported there)
#     625 # as a result, separate out the value mul
#     626 # Filed https://github.com/pytorch/pytorch/issues/139795
#     627 if isinstance(beta2, torch.Tensor):
#
# KeyboardInterrupt:

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/merged_data.csv --seed 42 --epochs 3000 --log_interval 500 --cuda --hidden_layers 7 --kernel_size 3 --dilation_coefficient 3 --use_cache --plot
# Out:
# Arguments: Namespace(cuda=True, epochs=3000, kernel_size=3, hidden_layers=7, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=42, dilation_coefficient=3, significance=0.8, plot=True, use_cache=True, ground_truth=None, data=['data/merged_data.csv'])
#
#  Dataset:  merged_data.csv
#
#  Analysis started for target:  松木山水库瞬时总流量
# Epoch:  1 [0%] 	Loss: 6675714.000000
# Epoch: 500 [17%] 	Loss: 749.383484
# Epoch: 1000 [33%] 	Loss: 447.532379
# Epoch: 1500 [50%] 	Loss: 3033.174805
# Epoch: 2000 [67%] 	Loss: 220.294312
# Epoch: 2500 [83%] 	Loss: 974.181274
# Epoch: 3000 [100%] 	Loss: 149.541473
# Potential causes:  [0, 313]
# Validated causes:  [0]
#
#  Analysis started for target:  松木山水库累计总水量
# Epoch:  1 [0%] 	Loss: 573309.000000
# Epoch: 500 [17%] 	Loss: 27.831751
# Epoch: 1000 [33%] 	Loss: 5.275884
# Epoch: 1500 [50%] 	Loss: 3.121544
# Epoch: 2000 [67%] 	Loss: 1.593968
# Epoch: 2500 [83%] 	Loss: 1.272353
# Epoch: 3000 [100%] 	Loss: 14.889753
# Potential causes:  [313, 1, 205]
# Validated causes:  [1]
#
#  Analysis started for target:  沙溪高位水池累计水量
# Epoch:  1 [0%] 	Loss: 96369744.000000
# Epoch: 500 [17%] 	Loss: 2021.920288
# Epoch: 1000 [33%] 	Loss: 918.213623
# Epoch: 1500 [50%] 	Loss: 902.067627
# Epoch: 2000 [67%] 	Loss: 366.843262
# Epoch: 2500 [83%] 	Loss: 262.249634
# Epoch: 3000 [100%] 	Loss: 2883.302734
# Potential causes:  [2, 191]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组  启动次数
# Epoch:  1 [0%] 	Loss: 5358.652832
# Epoch: 500 [17%] 	Loss: 1.488972
# Epoch: 1000 [33%] 	Loss: 0.359832
# Epoch: 1500 [50%] 	Loss: 0.139958
# Epoch: 2000 [67%] 	Loss: 0.082416
# Epoch: 2500 [83%] 	Loss: 0.056397
# Epoch: 3000 [100%] 	Loss: 0.061427
# Potential causes:  [141, 110]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组  机械事故停机次数
# Epoch:  1 [0%] 	Loss: 3664.129883
# Epoch: 500 [17%] 	Loss: 1.491310
# Epoch: 1000 [33%] 	Loss: 0.378166
# Epoch: 1500 [50%] 	Loss: 0.160240
# Epoch: 2000 [67%] 	Loss: 0.376220
# Epoch: 2500 [83%] 	Loss: 0.053305
# Epoch: 3000 [100%] 	Loss: 0.032286
# Potential causes:  [141, 79]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组  正常停机次数
# Epoch:  1 [0%] 	Loss: 3703.692383
# Epoch: 500 [17%] 	Loss: 1.803038
# Epoch: 1000 [33%] 	Loss: 0.392542
# Epoch: 1500 [50%] 	Loss: 0.154264
# Epoch: 2000 [67%] 	Loss: 0.093059
# Epoch: 2500 [83%] 	Loss: 0.051361
# Epoch: 3000 [100%] 	Loss: 0.033731
# Potential causes:  [141, 110]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组  电气事故停机次数
# Epoch:  1 [0%] 	Loss: 4546.341309
# Epoch: 500 [17%] 	Loss: 1.591318
# Epoch: 1000 [33%] 	Loss: 0.913906
# Epoch: 1500 [50%] 	Loss: 0.159545
# Epoch: 2000 [67%] 	Loss: 0.097366
# Epoch: 2500 [83%] 	Loss: 0.069825
# Epoch: 3000 [100%] 	Loss: 0.052317
# Potential causes:  [141, 110]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 10kV机组开关柜多功能电表 进线AB线电压
# Epoch:  1 [0%] 	Loss: 3994.088623
# Epoch: 500 [17%] 	Loss: 1.628980
# Epoch: 1000 [33%] 	Loss: 0.678399
# Epoch: 1500 [50%] 	Loss: 0.326357
# Epoch: 2000 [67%] 	Loss: 1.114864
# Epoch: 2500 [83%] 	Loss: 0.102857
# Epoch: 3000 [100%] 	Loss: 0.085033
# Potential causes:  [141, 110]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 10kV机组开关柜多功能电表 进线A相电流
# Epoch:  1 [0%] 	Loss: 3557.442383
# Epoch: 500 [17%] 	Loss: 1.791569
# Epoch: 1000 [33%] 	Loss: 0.274504
# Epoch: 1500 [50%] 	Loss: 0.084291
# Epoch: 2000 [67%] 	Loss: 0.056007
# Epoch: 2500 [83%] 	Loss: 0.035350
# Epoch: 3000 [100%] 	Loss: 0.195621
# Potential causes:  [141, 79]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 停机模式
# Epoch:  1 [0%] 	Loss: 3663.520508
# Epoch: 500 [17%] 	Loss: 3.412481
# Epoch: 1000 [33%] 	Loss: 1.111759
# Epoch: 1500 [50%] 	Loss: 0.386883
# Epoch: 2000 [67%] 	Loss: 0.634968
# Epoch: 2500 [83%] 	Loss: 0.138502
# Epoch: 3000 [100%] 	Loss: 0.657502
# Potential causes:  [141, 79]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 变频器 变频器频率
# Epoch:  1 [0%] 	Loss: 1703569024.000000
# Epoch: 500 [17%] 	Loss: 1356979.250000
# Epoch: 1000 [33%] 	Loss: 157870.656250
# Epoch: 1500 [50%] 	Loss: 81876.554688
# Epoch: 2000 [67%] 	Loss: 56739.871094
# Epoch: 2500 [83%] 	Loss: 2759372.750000
# Epoch: 3000 [100%] 	Loss: 1133870.750000
# Potential causes:  [217, 157]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 变频运行模式
# Epoch:  1 [0%] 	Loss: 3621.899414
# Epoch: 500 [17%] 	Loss: 1.342019
# Epoch: 1000 [33%] 	Loss: 0.679270
# Epoch: 1500 [50%] 	Loss: 0.165617
# Epoch: 2000 [67%] 	Loss: 0.104344
# Epoch: 2500 [83%] 	Loss: 0.085582
# Epoch: 3000 [100%] 	Loss: 0.046492
# Potential causes:  [141, 79, 91]
# Validated causes:  [91]
#
#  Analysis started for target:  罗田泵站 #1机组 变频进线保护 AB线电压
# Epoch:  1 [0%] 	Loss: 17116.265625
# Epoch: 500 [17%] 	Loss: 7.841671
# Epoch: 1000 [33%] 	Loss: 5.590900
# Epoch: 1500 [50%] 	Loss: 3.837713
# Epoch: 2000 [67%] 	Loss: 2.602737
# Epoch: 2500 [83%] 	Loss: 2.139732
# Epoch: 3000 [100%] 	Loss: 1.714622
# Potential causes:  [313, 32, 91]
# Validated causes:  [91]
#
#  Analysis started for target:  罗田泵站 #1机组 变频进线保护 进线A相电流
# Epoch:  1 [0%] 	Loss: 5047360946176.000000
# Epoch: 500 [17%] 	Loss: 1245426176.000000
# Epoch: 1000 [33%] 	Loss: 445458784.000000
# Epoch: 1500 [50%] 	Loss: 257699648.000000
# Epoch: 2000 [67%] 	Loss: 9411162112.000000
# Epoch: 2500 [83%] 	Loss: 203749376.000000
# Epoch: 3000 [100%] 	Loss: 99357704.000000
# Potential causes:  [22, 292, 13]
# Validated causes:  [13]
#
#  Analysis started for target:  罗田泵站 #1机组 工频运行模式
# Epoch:  1 [0%] 	Loss: 3557.442383
# Epoch: 500 [17%] 	Loss: 1.592255
# Epoch: 1000 [33%] 	Loss: 0.271468
# Epoch: 1500 [50%] 	Loss: 0.237554
# Epoch: 2000 [67%] 	Loss: 0.064676
# Epoch: 2500 [83%] 	Loss: 0.036533
# Epoch: 3000 [100%] 	Loss: 0.021793
# Potential causes:  [141, 79]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 本次运行时间 机组本次运行时间_天
# Epoch:  1 [0%] 	Loss: 3704.944580
# Epoch: 500 [17%] 	Loss: 1.591265
# Epoch: 1000 [33%] 	Loss: 0.856192
# Epoch: 1500 [50%] 	Loss: 0.161716
# Epoch: 2000 [67%] 	Loss: 0.095146
# Epoch: 2500 [83%] 	Loss: 0.063885
# Epoch: 3000 [100%] 	Loss: 1.133737
# Potential causes:  [141, 79, 110]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 检修阀出口压力 测量值
# Epoch:  1 [0%] 	Loss: 3566.955811
# Epoch: 500 [17%] 	Loss: 1.615354
# Epoch: 1000 [33%] 	Loss: 0.293329
# Epoch: 1500 [50%] 	Loss: 0.084692
# Epoch: 2000 [67%] 	Loss: 0.908535
# Epoch: 2500 [83%] 	Loss: 0.042164
# Epoch: 3000 [100%] 	Loss: 0.025672
# Potential causes:  [141, 79]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 水泵运行扬程（差压) 测量值
# Epoch:  1 [0%] 	Loss: 3561.808594
# Epoch: 500 [17%] 	Loss: 1.630020
# Epoch: 1000 [33%] 	Loss: 0.289829
# Epoch: 1500 [50%] 	Loss: 0.121584
# Epoch: 2000 [67%] 	Loss: 0.053323
# Epoch: 2500 [83%] 	Loss: 0.038794
# Epoch: 3000 [100%] 	Loss: 0.025805
# Potential causes:  [141, 79]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 电机辅助控制柜 转速值
# Epoch:  1 [0%] 	Loss: 16082807808.000000
# Epoch: 500 [17%] 	Loss: 3357653.750000
# Epoch: 1000 [33%] 	Loss: 1094821.000000
# Epoch: 1500 [50%] 	Loss: 772711.437500
# Epoch: 2000 [67%] 	Loss: 554677.687500
# Epoch: 2500 [83%] 	Loss: 451794.812500
# Epoch: 3000 [100%] 	Loss: 312548.343750
# Potential causes:  [18, 292]
# Validated causes:  [18]
#
#  Analysis started for target:  罗田泵站 #1机组 累计运行时间 机组本次运行时间_天
# Epoch:  1 [0%] 	Loss: 7987.527832
# Epoch: 500 [17%] 	Loss: 1.368767
# Epoch: 1000 [33%] 	Loss: 0.281820
# Epoch: 1500 [50%] 	Loss: 0.519755
# Epoch: 2000 [67%] 	Loss: 0.071509
# Epoch: 2500 [83%] 	Loss: 2.648643
# Epoch: 3000 [100%] 	Loss: 0.031621
# Potential causes:  [141, 269]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 累计运行时间 机组本次运行时间_时
# Epoch:  1 [0%] 	Loss: 3994.108398
# Epoch: 500 [17%] 	Loss: 12.004469
# Epoch: 1000 [33%] 	Loss: 7.227468
# Epoch: 1500 [50%] 	Loss: 1.804451
# Epoch: 2000 [67%] 	Loss: 0.226087
# Epoch: 2500 [83%] 	Loss: 0.090127
# Epoch: 3000 [100%] 	Loss: 0.048590
# Potential causes:  [141, 20]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 进水管进口压力 测量值
# Epoch:  1 [0%] 	Loss: 3557.434814
# Epoch: 500 [17%] 	Loss: 1.579178
# Epoch: 1000 [33%] 	Loss: 0.268783
# Epoch: 1500 [50%] 	Loss: 0.086544
# Epoch: 2000 [67%] 	Loss: 0.067566
# Epoch: 2500 [83%] 	Loss: 0.030425
# Epoch: 3000 [100%] 	Loss: 0.019097
# Potential causes:  [141, 79]
# Validated causes:  []
#
#  Analysis started for target:  罗田泵站 #1机组 量水间流量计 瞬时流量
# Epoch:  1 [0%] 	Loss: 82121.765625
# Epoch: 500 [17%] 	Loss: 10.824038
# Epoch: 1000 [33%] 	Loss: 3.866287
# Epoch: 1500 [50%] 	Loss: 2.417600
# Epoch: 2000 [67%] 	Loss: 1.914137
# Epoch: 2500 [83%] 	Loss: 1.521300
# Epoch: 3000 [100%] 	Loss: 41.436424
# Potential causes:  [22, 214]
# Validated causes:  [22]
#
#  Analysis started for target:  罗田泵站 #2机组  启动次数
# Epoch:  1 [0%] 	Loss: 3557.442383
# Epoch: 500 [17%] 	Loss: 1.592184
# Epoch: 1000 [33%] 	Loss: 0.320251
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/work/runTCDF.py:541
#     539 for dataset in args.data:
#     540   datafiles[dataset] = ""
# --> 541 main(datafiles, evaluation=False)
#
# File ~/work/runTCDF.py:355, in main(datafiles, evaluation)
#     352 print("\n Dataset: ", stringdatafile)
#     354 # run TCDF with cache option
# --> 355 allcauses, alldelays, allreallosses, allscores, columns = runTCDF(
#     356     datafile, use_cache=args.use_cache
#     357 )
#     359 print(
#     360     "\n===================Results for", stringdatafile,
#     361     "=================================="
#     362 )
#     363 for pair in alldelays:
#
# File ~/work/runTCDF.py:270, in runTCDF(datafile, use_cache)
#     268 for c in columns:
#     269   idx = df_data.columns.get_loc(c)
# --> 270   causes, causeswithdelay, realloss, scores = TCDF.findcauses(
#     271       c,
#     272       cuda=cuda,
#     273       epochs=nrepochs,
#     274       kernel_size=kernel_size,
#     275       layers=levels,
#     276       log_interval=loginterval,
#     277       lr=learningrate,
#     278       optimizername=optimizername,
#     279       seed=seed,
#     280       dilation_c=dilation_c,
#     281       significance=significance,
#     282       file=datafile
#     283   )
#     285   allscores[idx] = scores
#     286   allcauses[idx] = causes
#
# File ~/work/TCDF.py:96, in findcauses(target, cuda, epochs, kernel_size, layers, log_interval, lr, optimizername, seed, dilation_c, significance, file)
#      94 firstloss = firstloss.item()
#      95 for ep in range(2, epochs + 1):
# ---> 96   scores, realloss = train(
#      97       ep, X_train, Y_train, model, optimizer, log_interval, epochs
#      98   )
#      99 realloss = realloss.item()
#     101 s = sorted(scores.view(-1).cpu().detach().numpy(), reverse=True)
#
# File ~/work/TCDF.py:46, in train(epoch, traindata, traintarget, modelname, optimizer, log_interval, epochs)
#      43 attentionscores = modelname.fs_attention
#      45 loss = F.mse_loss(output, y)
# ---> 46 loss.backward()
#      47 optimizer.step()
#      49 if epoch % log_interval == 0 or epoch % epochs == 0 or epoch == 1:
#
# File /opt/conda/lib/python3.11/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/merged_data.csv --seed 42 --epochs 3000 --log_interval 500 --cuda --hidden_layers 7 --kernel_size 3 --dilation_coefficient 3 --plot
# Out:
# Arguments: Namespace(cuda=True, epochs=3000, kernel_size=3, hidden_layers=7, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=42, dilation_coefficient=3, significance=0.8, plot=True, use_cache=False, normalization='zscore', n_jobs=-1, ground_truth=None, data=['data/merged_data.csv'])
#
#  Dataset:  merged_data.csv
# 应用zscore归一化，并行处理 (32 进程)...
#   警告: 列 '罗田泵站 #1机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #1机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #1机组 10kV机组开关柜多功能电表 进线A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #1机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组 10kV机组开关柜多功能电表 进线A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组 10kV机组开关柜多功能电表 进线A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组 10kV机组开关柜多功能电表 进线A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '高新沙泵站 #3机组 机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '高新沙泵站 #5机组 机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组 10kV机组开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组 10kV机组开关柜多功能电表 输入有功电度' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组 10kV机组开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组 开关柜多功能电表 输入有功电度' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组 开关柜多功能电表 输入有功电度' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组 开关柜多功能电表 输入有功电度' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组 开关柜多功能电表 输入有功电度' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
# 处理列 1/370: 松木山水库瞬时总流量
#   计算因果关系...

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/merged_data.csv --seed 42 --epochs 3000 --log_interval 500 --cuda --hidden_layers 7 --kernel_size 3 --dilation_coefficient 3 --plot  --use_cache
# Out:
# Arguments: Namespace(cuda=True, epochs=3000, kernel_size=3, hidden_layers=7, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=42, dilation_coefficient=3, significance=0.8, plot=True, use_cache=True, normalization='zscore', n_jobs=-1, ground_truth=None, data=['data/merged_data.csv'])
#
#  Dataset:  merged_data.csv
# 应用zscore归一化，并行处理 (32 进程)...
#   警告: 列 '罗田泵站 #1机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #1机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #1机组 10kV机组开关柜多功能电表 进线A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #1机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组 10kV机组开关柜多功能电表 进线A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #2机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组 10kV机组开关柜多功能电表 进线A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #3机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组 10kV机组开关柜多功能电表 进线A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '罗田泵站 #4机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '高新沙泵站 #3机组 机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '高新沙泵站 #5机组 机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组 10kV机组开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组 10kV机组开关柜多功能电表 输入有功电度' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #1机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组 10kV机组开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #2机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #3机组 开关柜多功能电表 输入有功电度' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #4机组 开关柜多功能电表 输入有功电度' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #5机组 开关柜多功能电表 输入有功电度' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #6机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #7机组 开关柜多功能电表 输入有功电度' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组  启动次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组  机械事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组  正常停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组  电气事故停机次数' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组 工频运行模式' 是常数列或包含NaN值，将其替换为0
#   警告: 列 '鲤鱼洲泵站 #8机组 开关柜多功能电表 A相电流' 是常数列或包含NaN值，将其替换为0
# 找到数据集缓存: data/merged_data.csv
# 处理列 1/370: 松木山水库瞬时总流量
#   使用缓存的结果
# 处理列 2/370: 松木山水库累计总水量
#   使用缓存的结果
# 处理列 3/370: 沙溪高位水池累计水量
#   使用缓存的结果
# 处理列 4/370: 罗田泵站 #1机组  启动次数
#   使用缓存的结果
# 处理列 5/370: 罗田泵站 #1机组  机械事故停机次数
#   使用缓存的结果
# 处理列 6/370: 罗田泵站 #1机组  正常停机次数
#   使用缓存的结果
# 处理列 7/370: 罗田泵站 #1机组  电气事故停机次数
#   使用缓存的结果
# 处理列 8/370: 罗田泵站 #1机组 10kV机组开关柜多功能电表 进线AB线电压
#   使用缓存的结果
# 处理列 9/370: 罗田泵站 #1机组 10kV机组开关柜多功能电表 进线A相电流
#   使用缓存的结果
# 处理列 10/370: 罗田泵站 #1机组 停机模式
#   使用缓存的结果
# 处理列 11/370: 罗田泵站 #1机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 12/370: 罗田泵站 #1机组 变频运行模式
#   使用缓存的结果
# 处理列 13/370: 罗田泵站 #1机组 变频进线保护 AB线电压
#   使用缓存的结果
# 处理列 14/370: 罗田泵站 #1机组 变频进线保护 进线A相电流
#   使用缓存的结果
# 处理列 15/370: 罗田泵站 #1机组 工频运行模式
#   使用缓存的结果
# 处理列 16/370: 罗田泵站 #1机组 本次运行时间 机组本次运行时间_天
#   使用缓存的结果
# 处理列 17/370: 罗田泵站 #1机组 检修阀出口压力 测量值
#   使用缓存的结果
# 处理列 18/370: 罗田泵站 #1机组 水泵运行扬程（差压) 测量值
#   使用缓存的结果
# 处理列 19/370: 罗田泵站 #1机组 电机辅助控制柜 转速值
#   使用缓存的结果
# 处理列 20/370: 罗田泵站 #1机组 累计运行时间 机组本次运行时间_天
#   使用缓存的结果
# 处理列 21/370: 罗田泵站 #1机组 累计运行时间 机组本次运行时间_时
#   使用缓存的结果
# 处理列 22/370: 罗田泵站 #1机组 进水管进口压力 测量值
#   使用缓存的结果
# 处理列 23/370: 罗田泵站 #1机组 量水间流量计 瞬时流量
#   使用缓存的结果
# 处理列 24/370: 罗田泵站 #2机组  启动次数
#   使用缓存的结果
# 处理列 25/370: 罗田泵站 #2机组  机械事故停机次数
#   使用缓存的结果
# 处理列 26/370: 罗田泵站 #2机组  正常停机次数
#   使用缓存的结果
# 处理列 27/370: 罗田泵站 #2机组  电气事故停机次数
#   使用缓存的结果
# 处理列 28/370: 罗田泵站 #2机组 10kV机组开关柜多功能电表 进线AB线电压
#   使用缓存的结果
# 处理列 29/370: 罗田泵站 #2机组 10kV机组开关柜多功能电表 进线A相电流
#   使用缓存的结果
# 处理列 30/370: 罗田泵站 #2机组 停机模式
#   使用缓存的结果
# 处理列 31/370: 罗田泵站 #2机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 32/370: 罗田泵站 #2机组 变频运行模式
#   使用缓存的结果
# 处理列 33/370: 罗田泵站 #2机组 变频进线保护 AB线电压
#   使用缓存的结果
# 处理列 34/370: 罗田泵站 #2机组 变频进线保护 进线A相电流
#   使用缓存的结果
# 处理列 35/370: 罗田泵站 #2机组 工频运行模式
#   使用缓存的结果
# 处理列 36/370: 罗田泵站 #2机组 本次运行时间 机组本次运行时间_天
#   使用缓存的结果
# 处理列 37/370: 罗田泵站 #2机组 检修阀出口压力 测量值
#   使用缓存的结果
# 处理列 38/370: 罗田泵站 #2机组 水泵运行扬程（差压) 测量值
#   使用缓存的结果
# 处理列 39/370: 罗田泵站 #2机组 电机辅助控制柜 转速值
#   使用缓存的结果
# 处理列 40/370: 罗田泵站 #2机组 累计运行时间 机组本次运行时间_天
#   使用缓存的结果
# 处理列 41/370: 罗田泵站 #2机组 累计运行时间 机组本次运行时间_时
#   使用缓存的结果
# 处理列 42/370: 罗田泵站 #2机组 进水管进口压力 测量值
#   使用缓存的结果
# 处理列 43/370: 罗田泵站 #2机组 量水间流量计 瞬时流量
#   使用缓存的结果
# 处理列 44/370: 罗田泵站 #3机组  启动次数
#   使用缓存的结果
# 处理列 45/370: 罗田泵站 #3机组  机械事故停机次数
#   使用缓存的结果
# 处理列 46/370: 罗田泵站 #3机组  正常停机次数
#   使用缓存的结果
# 处理列 47/370: 罗田泵站 #3机组  电气事故停机次数
#   使用缓存的结果
# 处理列 48/370: 罗田泵站 #3机组 10kV机组开关柜多功能电表 进线AB线电压
#   使用缓存的结果
# 处理列 49/370: 罗田泵站 #3机组 10kV机组开关柜多功能电表 进线A相电流
#   使用缓存的结果
# 处理列 50/370: 罗田泵站 #3机组 停机模式
#   使用缓存的结果
# 处理列 51/370: 罗田泵站 #3机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 52/370: 罗田泵站 #3机组 变频运行模式
#   使用缓存的结果
# 处理列 53/370: 罗田泵站 #3机组 变频进线保护 AB线电压
#   使用缓存的结果
# 处理列 54/370: 罗田泵站 #3机组 变频进线保护 进线A相电流
#   使用缓存的结果
# 处理列 55/370: 罗田泵站 #3机组 工频运行模式
#   使用缓存的结果
# 处理列 56/370: 罗田泵站 #3机组 本次运行时间 机组本次运行时间_天
#   使用缓存的结果
# 处理列 57/370: 罗田泵站 #3机组 检修阀出口压力 测量值
#   使用缓存的结果
# 处理列 58/370: 罗田泵站 #3机组 水泵扬程 测量值
#   使用缓存的结果
# 处理列 59/370: 罗田泵站 #3机组 水泵运行扬程（差压) 测量值
#   使用缓存的结果
# 处理列 60/370: 罗田泵站 #3机组 电机辅助控制柜 转速值
#   使用缓存的结果
# 处理列 61/370: 罗田泵站 #3机组 累计运行时间 机组本次运行时间_天
#   使用缓存的结果
# 处理列 62/370: 罗田泵站 #3机组 累计运行时间 机组本次运行时间_时
#   使用缓存的结果
# 处理列 63/370: 罗田泵站 #3机组 进水管进口压力 测量值
#   使用缓存的结果
# 处理列 64/370: 罗田泵站 #3机组 量水间流量计 瞬时流量
#   使用缓存的结果
# 处理列 65/370: 罗田泵站 #4机组  启动次数
#   使用缓存的结果
# 处理列 66/370: 罗田泵站 #4机组  机械事故停机次数
#   使用缓存的结果
# 处理列 67/370: 罗田泵站 #4机组  正常停机次数
#   使用缓存的结果
# 处理列 68/370: 罗田泵站 #4机组  电气事故停机次数
#   使用缓存的结果
# 处理列 69/370: 罗田泵站 #4机组 10kV机组开关柜多功能电表 进线AB线电压
#   使用缓存的结果
# 处理列 70/370: 罗田泵站 #4机组 10kV机组开关柜多功能电表 进线A相电流
#   使用缓存的结果
# 处理列 71/370: 罗田泵站 #4机组 停机模式
#   使用缓存的结果
# 处理列 72/370: 罗田泵站 #4机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 73/370: 罗田泵站 #4机组 变频运行模式
#   使用缓存的结果
# 处理列 74/370: 罗田泵站 #4机组 变频进线保护 AB线电压
#   使用缓存的结果
# 处理列 75/370: 罗田泵站 #4机组 变频进线保护 进线A相电流
#   使用缓存的结果
# 处理列 76/370: 罗田泵站 #4机组 工频运行模式
#   使用缓存的结果
# 处理列 77/370: 罗田泵站 #4机组 本次运行时间 机组本次运行时间_天
#   使用缓存的结果
# 处理列 78/370: 罗田泵站 #4机组 检修阀出口压力 测量值
#   使用缓存的结果
# 处理列 79/370: 罗田泵站 #4机组 水泵运行扬程（差压) 测量值
#   使用缓存的结果
# 处理列 80/370: 罗田泵站 #4机组 电机辅助控制柜 转速值
#   使用缓存的结果
# 处理列 81/370: 罗田泵站 #4机组 累计运行时间 机组本次运行时间_天
#   使用缓存的结果
# 处理列 82/370: 罗田泵站 #4机组 累计运行时间 机组本次运行时间_时
#   使用缓存的结果
# 处理列 83/370: 罗田泵站 #4机组 进水管进口压力 测量值
#   使用缓存的结果
# 处理列 84/370: 罗田泵站 #4机组 量水间流量计 瞬时流量
#   使用缓存的结果
# 处理列 85/370: 罗田泵站 出口水量 测量值
#   使用缓存的结果
# 处理列 86/370: 罗田泵站 出口流量 测量值
#   使用缓存的结果
# 处理列 87/370: 罗田泵站 数字仪表 前池水位 测量值
#   使用缓存的结果
# 处理列 88/370: 罗田泵站 进库闸流量计瞬时流量汇总 测量值
#   使用缓存的结果
# 处理列 89/370: 罗田泵站 进库闸流量计累计流量汇总 测量值
#   使用缓存的结果
# 处理列 90/370: 高新沙泵站 #1机组 停机模式
#   使用缓存的结果
# 处理列 91/370: 高新沙泵站 #1机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 92/370: 高新沙泵站 #1机组 变频器切换柜 变频器功率
#   使用缓存的结果
# 处理列 93/370: 高新沙泵站 #1机组 变频运行模式
#   使用缓存的结果
# 处理列 94/370: 高新沙泵站 #1机组 多功能电表 进线AB线电压
#   使用缓存的结果
# 处理列 95/370: 高新沙泵站 #1机组 多功能电表 进线A相电流
#   使用缓存的结果
# 处理列 96/370: 高新沙泵站 #1机组 工频运行模式
#   使用缓存的结果
# 处理列 97/370: 高新沙泵站 #1机组 开机成功次数
#   使用缓存的结果
# 处理列 98/370: 高新沙泵站 #1机组 本次运行时间
#   使用缓存的结果
# 处理列 99/370: 高新沙泵站 #1机组 机械事故停机次数
#   使用缓存的结果
# 处理列 100/370: 高新沙泵站 #1机组 检修阀出口压力 测量值
#   使用缓存的结果
# 处理列 101/370: 高新沙泵站 #1机组 正常停机次数
#   使用缓存的结果
# 处理列 102/370: 高新沙泵站 #1机组 水泵扬程 测量值
#   使用缓存的结果
# 处理列 103/370: 高新沙泵站 #1机组 电机测温测速制动屏 转速值
#   使用缓存的结果
# 处理列 104/370: 高新沙泵站 #1机组 电气事故停机次数
#   使用缓存的结果
# 处理列 105/370: 高新沙泵站 #1机组 累计运行时间
#   使用缓存的结果
# 处理列 106/370: 高新沙泵站 #1机组 进水管进口压力 测量值
#   使用缓存的结果
# 处理列 107/370: 高新沙泵站 #1机组 量水间流量计 瞬时流量
#   使用缓存的结果
# 处理列 108/370: 高新沙泵站 #2机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 109/370: 高新沙泵站 #2机组 变频器切换柜 变频器功率
#   使用缓存的结果
# 处理列 110/370: 高新沙泵站 #2机组 变频运行模式
#   使用缓存的结果
# 处理列 111/370: 高新沙泵站 #2机组 多功能电表 进线AB线电压
#   使用缓存的结果
# 处理列 112/370: 高新沙泵站 #2机组 多功能电表 进线A相电流
#   使用缓存的结果
# 处理列 113/370: 高新沙泵站 #2机组 工频运行模式
#   使用缓存的结果
# 处理列 114/370: 高新沙泵站 #2机组 本次运行时间
#   使用缓存的结果
# 处理列 115/370: 高新沙泵站 #2机组 检修阀出口压力 测量值
#   使用缓存的结果
# 处理列 116/370: 高新沙泵站 #2机组 正常停机次数
#   使用缓存的结果
# 处理列 117/370: 高新沙泵站 #2机组 电机测温测速制动屏 转速值
#   使用缓存的结果
# 处理列 118/370: 高新沙泵站 #2机组 电气事故停机次数
#   使用缓存的结果
# 处理列 119/370: 高新沙泵站 #2机组 进水管进口压力 测量值
#   使用缓存的结果
# 处理列 120/370: 高新沙泵站 #2机组 量水间流量计 瞬时流量
#   使用缓存的结果
# 处理列 121/370: 高新沙泵站 #3机组 停机模式
#   使用缓存的结果
# 处理列 122/370: 高新沙泵站 #3机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 123/370: 高新沙泵站 #3机组 变频器切换柜 变频器功率
#   使用缓存的结果
# 处理列 124/370: 高新沙泵站 #3机组 多功能电表 进线AB线电压
#   使用缓存的结果
# 处理列 125/370: 高新沙泵站 #3机组 工频运行模式
#   使用缓存的结果
# 处理列 126/370: 高新沙泵站 #3机组 开机成功次数
#   使用缓存的结果
# 处理列 127/370: 高新沙泵站 #3机组 本次运行时间
#   使用缓存的结果
# 处理列 128/370: 高新沙泵站 #3机组 机械事故停机次数
#   使用缓存的结果
# 处理列 129/370: 高新沙泵站 #3机组 水泵扬程 测量值
#   使用缓存的结果
# 处理列 130/370: 高新沙泵站 #3机组 电气事故停机次数
#   使用缓存的结果
# 处理列 131/370: 高新沙泵站 #3机组 累计运行时间
#   使用缓存的结果
# 处理列 132/370: 高新沙泵站 #3机组 进水管进口压力 测量值
#   使用缓存的结果
# 处理列 133/370: 高新沙泵站 #3机组 量水间流量计 瞬时流量
#   使用缓存的结果
# 处理列 134/370: 高新沙泵站 #4机组 停机模式
#   使用缓存的结果
# 处理列 135/370: 高新沙泵站 #4机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 136/370: 高新沙泵站 #4机组 多功能电表 进线A相电流
#   使用缓存的结果
# 处理列 137/370: 高新沙泵站 #4机组 工频运行模式
#   使用缓存的结果
# 处理列 138/370: 高新沙泵站 #4机组 开机成功次数
#   使用缓存的结果
# 处理列 139/370: 高新沙泵站 #4机组 本次运行时间
#   使用缓存的结果
# 处理列 140/370: 高新沙泵站 #4机组 检修阀出口压力 测量值
#   使用缓存的结果
# 处理列 141/370: 高新沙泵站 #4机组 正常停机次数
#   使用缓存的结果
# 处理列 142/370: 高新沙泵站 #4机组 水泵扬程 测量值
#   使用缓存的结果
# 处理列 143/370: 高新沙泵站 #4机组 电机测温测速制动屏 转速值
#   使用缓存的结果
# 处理列 144/370: 高新沙泵站 #4机组 电气事故停机次数
#   使用缓存的结果
# 处理列 145/370: 高新沙泵站 #4机组 累计运行时间
#   使用缓存的结果
# 处理列 146/370: 高新沙泵站 #4机组 量水间流量计 瞬时流量
#   使用缓存的结果
# 处理列 147/370: 高新沙泵站 #5机组 停机模式
#   使用缓存的结果
# 处理列 148/370: 高新沙泵站 #5机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 149/370: 高新沙泵站 #5机组 变频器切换柜 变频器功率
#   使用缓存的结果
# 处理列 150/370: 高新沙泵站 #5机组 变频运行模式
#   使用缓存的结果
# 处理列 151/370: 高新沙泵站 #5机组 多功能电表 进线A相电流
#   使用缓存的结果
# 处理列 152/370: 高新沙泵站 #5机组 工频运行模式
#   使用缓存的结果
# 处理列 153/370: 高新沙泵站 #5机组 开机成功次数
#   使用缓存的结果
# 处理列 154/370: 高新沙泵站 #5机组 本次运行时间
#   使用缓存的结果
# 处理列 155/370: 高新沙泵站 #5机组 机械事故停机次数
#   使用缓存的结果
# 处理列 156/370: 高新沙泵站 #5机组 检修阀出口压力 测量值
#   使用缓存的结果
# 处理列 157/370: 高新沙泵站 #5机组 正常停机次数
#   使用缓存的结果
# 处理列 158/370: 高新沙泵站 #5机组 水泵扬程 测量值
#   使用缓存的结果
# 处理列 159/370: 高新沙泵站 #5机组 电机测温测速制动屏 转速值
#   使用缓存的结果
# 处理列 160/370: 高新沙泵站 #5机组 电气事故停机次数
#   使用缓存的结果
# 处理列 161/370: 高新沙泵站 #5机组 累计运行时间
#   使用缓存的结果
# 处理列 162/370: 高新沙泵站 #5机组 进水管进口压力 测量值
#   使用缓存的结果
# 处理列 163/370: 高新沙泵站 #5机组 量水间流量计 瞬时流量
#   使用缓存的结果
# 处理列 164/370: 高新沙泵站 #6机组 停机模式
#   使用缓存的结果
# 处理列 165/370: 高新沙泵站 #6机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 166/370: 高新沙泵站 #6机组 变频器切换柜 变频器功率
#   使用缓存的结果
# 处理列 167/370: 高新沙泵站 #6机组 变频运行模式
#   使用缓存的结果
# 处理列 168/370: 高新沙泵站 #6机组 多功能电表 进线AB线电压
#   使用缓存的结果
# 处理列 169/370: 高新沙泵站 #6机组 多功能电表 进线A相电流
#   使用缓存的结果
# 处理列 170/370: 高新沙泵站 #6机组 工频运行模式
#   使用缓存的结果
# 处理列 171/370: 高新沙泵站 #6机组 开机成功次数
#   使用缓存的结果
# 处理列 172/370: 高新沙泵站 #6机组 本次运行时间
#   使用缓存的结果
# 处理列 173/370: 高新沙泵站 #6机组 机械事故停机次数
#   使用缓存的结果
# 处理列 174/370: 高新沙泵站 #6机组 检修阀出口压力 测量值
#   使用缓存的结果
# 处理列 175/370: 高新沙泵站 #6机组 正常停机次数
#   使用缓存的结果
# 处理列 176/370: 高新沙泵站 #6机组 水泵扬程 测量值
#   使用缓存的结果
# 处理列 177/370: 高新沙泵站 #6机组 电机测温测速制动屏 转速值
#   使用缓存的结果
# 处理列 178/370: 高新沙泵站 #6机组 电气事故停机次数
#   使用缓存的结果
# 处理列 179/370: 高新沙泵站 #6机组 累计运行时间
#   使用缓存的结果
# 处理列 180/370: 高新沙泵站 #6机组 进水管进口压力 测量值
#   使用缓存的结果
# 处理列 181/370: 高新沙泵站 #6机组 量水间流量计 瞬时流量
#   使用缓存的结果
# 处理列 182/370: 高新沙泵站 出口水量
#   使用缓存的结果
# 处理列 183/370: 高新沙泵站 出口流量
#   使用缓存的结果
# 处理列 184/370: 高新沙泵站 南沙支线 瞬时总流量 测量值
#   使用缓存的结果
# 处理列 185/370: 高新沙泵站 南沙支线 累计总水量 测量值
#   使用缓存的结果
# 处理列 186/370: 高新沙泵站 机组变频器#1进线保护 进线AB线电压
#   使用缓存的结果
# 处理列 187/370: 高新沙泵站 机组变频器#1进线保护 进线A相电流
#   使用缓存的结果
# 处理列 188/370: 高新沙泵站 沙溪高位水池液位 测量值
#   使用缓存的结果
# 处理列 189/370: 高新沙泵站 泵站前池水位 测量值
#   使用缓存的结果
# 处理列 190/370: 高新沙泵站 调压塔水位 测量值
#   使用缓存的结果
# 处理列 191/370: 高新沙泵站 进库闸右线流量计 瞬时流量
#   使用缓存的结果
# 处理列 192/370: 高新沙泵站 进库闸右线流量计 累计水量
#   使用缓存的结果
# 处理列 193/370: 高新沙泵站 进库闸右线液位 测量值
#   使用缓存的结果
# 处理列 194/370: 高新沙泵站 进库闸左线流量计 瞬时流量
#   使用缓存的结果
# 处理列 195/370: 高新沙泵站 进库闸左线流量计 累计水量
#   使用缓存的结果
# 处理列 196/370: 鲤鱼洲泵站 #1机组  启动次数
#   使用缓存的结果
# 处理列 197/370: 鲤鱼洲泵站 #1机组  机械事故停机次数
#   使用缓存的结果
# 处理列 198/370: 鲤鱼洲泵站 #1机组  正常停机次数
#   使用缓存的结果
# 处理列 199/370: 鲤鱼洲泵站 #1机组  电气事故停机次数
#   使用缓存的结果
# 处理列 200/370: 鲤鱼洲泵站 #1机组 10kV机组开关柜多功能电表 A相电压
#   使用缓存的结果
# 处理列 201/370: 鲤鱼洲泵站 #1机组 10kV机组开关柜多功能电表 A相电流
#   使用缓存的结果
# 处理列 202/370: 鲤鱼洲泵站 #1机组 10kV机组开关柜多功能电表 输入有功电度
#   使用缓存的结果
# 处理列 203/370: 鲤鱼洲泵站 #1机组 停机模式
#   使用缓存的结果
# 处理列 204/370: 鲤鱼洲泵站 #1机组 出水检修阀 出口压力
#   使用缓存的结果
# 处理列 205/370: 鲤鱼洲泵站 #1机组 出水检修阀 进口压力
#   使用缓存的结果
# 处理列 206/370: 鲤鱼洲泵站 #1机组 变频器 变频器频率
#   使用缓存的结果
# 处理列 207/370: 鲤鱼洲泵站 #1机组 变频器 输出功率
#   使用缓存的结果
# 处理列 208/370: 鲤鱼洲泵站 #1机组 变频运行模式
#   使用缓存的结果
# 处理列 209/370: 鲤鱼洲泵站 #1机组 变频进线保护 进线A相电压
#   使用缓存的结果
# 处理列 210/370: 鲤鱼洲泵站 #1机组 变频进线保护 进线A相电流
#   使用缓存的结果
# 处理列 211/370: 鲤鱼洲泵站 #1机组 变频进线保护 进线有功功率
#   使用缓存的结果
# 处理列 212/370: 鲤鱼洲泵站 #1机组 工频运行模式
#   使用缓存的结果
# 处理列 213/370: 鲤鱼洲泵站 #1机组 本次运行时间 测量值
#   使用缓存的结果
# 处理列 214/370: 鲤鱼洲泵站 #1机组 水泵扬程 测量值
#   使用缓存的结果
# 处理列 215/370: 鲤鱼洲泵站 #1机组 电机测速装置 转速值
#   计算因果关系...
#
#  Analysis started for target:  鲤鱼洲泵站 #1机组 电机测速装置 转速值
# Epoch:  1 [0%] 	Loss: 1.000928

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/demo_dataset.csv=data/demo_groundtruth.csv  --epochs 500 --log_interval 250 --plot --cuda
# Out:
# Arguments: Namespace(cuda=True, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/demo_dataset.csv': 'data/demo_groundtruth.csv'}, data=None)
#
#  Dataset:  demo_dataset.csv
#
#  Analysis started for target:  Timeser0
# Epoch:  1 [0%] 	Loss: 2.315027
# Epoch: 250 [50%] 	Loss: 1.697025
# Epoch: 500 [100%] 	Loss: 1.695515
# Potential causes:  [np.int64(1), np.int64(2)]
# Validated causes:  []
#
#  Analysis started for target:  Timeser1
# Epoch:  1 [0%] 	Loss: 4.291189
# Epoch: 250 [50%] 	Loss: 0.002199
# Epoch: 500 [100%] 	Loss: 0.002134
# Potential causes:  [np.int64(0)]
# Validated causes:  [np.int64(0)]
#
#  Analysis started for target:  Timeser2
# Epoch:  1 [0%] 	Loss: 1.740447
# Epoch: 250 [50%] 	Loss: 0.365181
# Epoch: 500 [100%] 	Loss: 0.364763
# Potential causes:  [np.int64(1), np.int64(0)]
# Validated causes:  [np.int64(1)]
#
#  Analysis started for target:  Timeser3
# Epoch:  1 [0%] 	Loss: 2.264087
# Epoch: 250 [50%] 	Loss: 1.658579
# Epoch: 500 [100%] 	Loss: 1.657545
# Potential causes:  [np.int64(3), np.int64(1)]
# Validated causes:  []
#
# ===================Results for demo_dataset.csv ==================================
# Timeser0 causes Timeser1 with a delay of 1 time steps.
# Timeser1 causes Timeser2 with a delay of 2 time steps.
#
# ===================Evaluation for demo_dataset.csv ===============================
# Total False Positives':  0
# Total True Positives':  2
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  2
# TPs':  [(1, np.int64(0)), (2, np.int64(1))]
# FPs':  []
# TPs direct:  [(1, np.int64(0)), (2, np.int64(1))]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/demo_dataset.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/demo_dataset.csv'])
#
#  Analysis started for target:  Timeser0
# Epoch:  1 [0%] 	Loss: 2.302341
# Epoch: 500 [50%] 	Loss: 1.684893
# Epoch: 1000 [100%] 	Loss: 1.684635
#
#  Analysis started for target:  Timeser1
# Epoch:  1 [0%] 	Loss: 4.267725
# Epoch: 500 [50%] 	Loss: 0.002414
# Epoch: 1000 [100%] 	Loss: 0.002391
#
#  Analysis started for target:  Timeser2
# Epoch:  1 [0%] 	Loss: 1.714814
# Epoch: 500 [50%] 	Loss: 0.357675
# Epoch: 1000 [100%] 	Loss: 0.357274
#
#  Analysis started for target:  Timeser3
# Epoch:  1 [0%] 	Loss: 2.279164
# Epoch: 500 [50%] 	Loss: 1.672744
# Epoch: 1000 [100%] 	Loss: 1.671474
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/demo_dataset.csv : 0.46830029443873517 with standard deviation 0.30809262884646255
